# %% [markdown]
# # Parte 1 🥇

# %% [markdown]
# # Baixa corpus ⬇⬇⬇

# %%
import os
import zipfile
import pandas as pd

data_path = "data"
if not os.path.exists(data_path):
  # Baixa arquivo corpus.zip
  url = "https://raw.githubusercontent.com/AngryLeaderBB/NLP_class_2024/refs/" \
        "heads/main/Atividade_3/csvs.zip"
  cmd = ! wget {url}

  # Extrai corpus.zip na pasta corpus
  with zipfile.ZipFile("csvs.zip", 'r') as zip_ref:
      zip_ref.extractall(".")

  # Renomea a pasta csvs para data
  os.rename("csvs", data_path)

  # Exclui arquivo corpus.zip
  os.remove("csvs.zip")

csv_path = data_path + "/Dmoz-Health.csv"

# Carrega o csv no path csv_path
data = pd.read_csv(csv_path)

# %% [markdown]
# Imprime parte do corpus

# %%
print(f'file names:\n{data["file_name"]}\n----------')
print(f'texts:\n{data["text"]}\n----------')
print(f'classes:\n{data["class"]}')
# Out:
# file names:
# 0              1578510.txt
# 1              1577747.txt
# 2              1578166.txt
# 3              1577381.txt
# 4              1578793.txt
#                ...
# 6495    Health_1628926.txt
# 6496    Health_1628556.txt
# 6497    Health_1628984.txt
# 6498    Health_1628509.txt
# 6499    Health_1628699.txt
# Name: file_name, Length: 6500, dtype: object
# ----------
# texts:
# 0       Illinois Church Action on Alcohol and Addictio...
# 1       AA Statewide Meeting lists for all of Vermont....
# 2       Gracer Medical Group Dr. Richard Gracer is a p...
# 3       Phoenix Meetings, events, and visitor informat...
# 4       American River Area Narcotics Anonymous Resour...
#                               ...
# 6495    Alzheimer's Family Day Center Located in Falls...
# 6496    Chancellor Health Partners Assisted Living and...
# 6497    Resources For Aging, Inc. Publisher of "The Ca...
# 6498    Lourdesville Nursing Home A purpose built nurs...
# 6499    Assisted Living in Florida Directory of Adult ...
# Name: text, Length: 6500, dtype: object
# ----------
# classes:
# 0       Addictions
# 1       Addictions
# 2       Addictions
# 3       Addictions
# 4       Addictions
#            ...
# 6495        Senior
# 6496        Senior
# 6497        Senior
# 6498        Senior
# 6499        Senior
# Name: class, Length: 6500, dtype: object

# %% [markdown]
# # Baixa arquivo .py

# %%
import os

# Baixa o arquivo find_best_hyperparameters.py
if not os.path.exists("find_best_hyperparameters.py"):
  url = "https://raw.githubusercontent.com/AngryLeaderBB/NLP_class_2024/refs/" \
        "heads/main/Atividade_3/find_best_hyperparameters.py"
  cmd = ! wget {url}

# %% [markdown]
# # Divide o corpus em treino e teste ➗

# %%
import importlib
import os
import find_best_hyperparameters as fbh

importlib.reload(fbh)

# Initializa a classe BestParam com o path do csv e
# o path para salvar os resultados
bp = fbh.BestParam(csv_path, data_path)

# Divide os dados de treino/teste e salva no data_path
seed = 12345
bp.split_data(seed)

print("The data has been splited")
# Out:
# The data has been splited

# %% [markdown]
# Treina (Opcional, na próxima seção pode-se baixar resultados pré-treinados)

# %%
# Treina modelo e salva
bp.greedy_search(5)
print("The models has been trained")
# Out:
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# The models has been trained

# %% [markdown]
# # Parte 2 🥈

# %% [markdown]
# # Importa de dados base 🎲

# %%
import pandas as pd
from scipy.sparse import csr_matrix

# Carregar os dados de treino e teste
text_train = csr_matrix(pd.read_csv(data_path + "/text_train.csv"))
class_train = pd.read_csv(data_path + "/class_train.csv").squeeze()

text_test = csr_matrix(pd.read_csv(data_path + "/text_test.csv"))
class_test = pd.read_csv(data_path + "/class_test.csv").squeeze()

# %% [markdown]
# Carrega os Resultados do Greedy Search

# %%
# Carregar os resultados do Greedy Search
if not os.path.exists(data_path + "/model_search_results.csv"):
  url = "https://raw.githubusercontent.com/AngryLeaderBB/NLP_class_2024/refs/" \
        "heads/main/Atividade_3/model_search_results1.csv"

  cmd = ! wget {url}

  os.rename("model_search_results1.csv", "model_search_results.csv")

  # !mv model_search_results.csv {data_path}

search_results = pd.read_csv(data_path + "/model_search_results.csv")

# Exibi os resultados do Greedy Search
print(search_results)
# Out:
#                  Model                                 Params  Mean Test Score
# 0   LogisticRegression       {'C': 10, 'solver': 'liblinear'}         0.821538
# 1   LogisticRegression      {'C': 100, 'solver': 'liblinear'}         0.820962
# 2   LogisticRegression        {'C': 1, 'solver': 'liblinear'}         0.818846
# 3   LogisticRegression           {'C': 10, 'solver': 'lbfgs'}         0.814038
# 4   LogisticRegression           {'C': 100, 'solver': 'saga'}         0.812885
# 5   LogisticRegression             {'C': 1, 'solver': 'saga'}         0.812115
# 6   LogisticRegression            {'C': 10, 'solver': 'saga'}         0.812115
# 7   LogisticRegression            {'C': 1, 'solver': 'lbfgs'}         0.808846
# 8   LogisticRegression          {'C': 100, 'solver': 'lbfgs'}         0.806923
# 9   LogisticRegression      {'C': 0.1, 'solver': 'liblinear'}         0.795385
# 10  LogisticRegression           {'C': 0.1, 'solver': 'saga'}         0.793846
# 11  LogisticRegression          {'C': 0.1, 'solver': 'lbfgs'}         0.790577
# 12  LogisticRegression          {'C': 0.01, 'solver': 'saga'}         0.708846
# 13  LogisticRegression     {'C': 0.01, 'solver': 'liblinear'}         0.704615
# 14  LogisticRegression         {'C': 0.01, 'solver': 'lbfgs'}         0.701923
# 15       MultinomialNB      {'alpha': 1.0, 'fit_prior': True}         0.796538
# 16       MultinomialNB     {'alpha': 1.0, 'fit_prior': False}         0.796538
# 17       MultinomialNB      {'alpha': 0.1, 'fit_prior': True}         0.794615
# 18       MultinomialNB     {'alpha': 0.1, 'fit_prior': False}         0.794423
# 19       MultinomialNB     {'alpha': 0.01, 'fit_prior': True}         0.781154
# 20       MultinomialNB    {'alpha': 0.01, 'fit_prior': False}         0.780962
# 21       MultinomialNB   {'alpha': 0.001, 'fit_prior': False}         0.763269
# 22       MultinomialNB    {'alpha': 0.001, 'fit_prior': True}         0.763077
# 23       MultinomialNB     {'alpha': 10.0, 'fit_prior': True}         0.738846
# 24       MultinomialNB    {'alpha': 10.0, 'fit_prior': False}         0.738654
# 25       MultinomialNB   {'alpha': 100.0, 'fit_prior': False}         0.627500
# 26       MultinomialNB    {'alpha': 100.0, 'fit_prior': True}         0.626538
# 27       MultinomialNB   {'alpha': 1000.0, 'fit_prior': True}         0.504038
# 28       MultinomialNB  {'alpha': 1000.0, 'fit_prior': False}         0.502692
# 29                 SVC           {'C': 1, 'kernel': 'linear'}         0.791154
# 30                 SVC          {'C': 10, 'kernel': 'linear'}         0.791154
# 31                 SVC         {'C': 100, 'kernel': 'linear'}         0.791154
# 32                 SVC         {'C': 0.1, 'kernel': 'linear'}         0.790192
# 33                 SVC             {'C': 10, 'kernel': 'rbf'}         0.775385
# 34                 SVC            {'C': 100, 'kernel': 'rbf'}         0.775385
# 35                 SVC              {'C': 1, 'kernel': 'rbf'}         0.746538
# 36                 SVC        {'C': 0.01, 'kernel': 'linear'}         0.692115
# 37                 SVC           {'C': 100, 'kernel': 'poly'}         0.646923
# 38                 SVC            {'C': 10, 'kernel': 'poly'}         0.633077
# 39                 SVC             {'C': 1, 'kernel': 'poly'}         0.460962
# 40                 SVC            {'C': 0.1, 'kernel': 'rbf'}         0.399808
# 41                 SVC           {'C': 0.1, 'kernel': 'poly'}         0.192885
# 42                 SVC           {'C': 0.01, 'kernel': 'rbf'}         0.097885
# 43                 SVC          {'C': 0.01, 'kernel': 'poly'}         0.083269

# %% [markdown]
# # Re-treina os Modelos 🤖

# %% [markdown]
# Multinomial Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# Recupera o melhor parametro com modelo MultinomialNB
best_params_arr = search_results.loc[
                    search_results['Model'] == 'MultinomialNB'].values[0]
print(best_params_arr)

best_params = eval(best_params_arr[1])

# Inicializa o modelo
model_nb = MultinomialNB(alpha=best_params["alpha"],
                         fit_prior=best_params["fit_prior"])

# Treina o modelo
model_nb.fit(text_train, class_train)
# Out:
# ['MultinomialNB' "{'alpha': 1.0, 'fit_prior': True}" 0.7965384615384614]
# MultinomialNB()

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# Recupera o melhor parametro com modelo LogisticRegression
best_params_arr = search_results.loc[
                      search_results['Model'] == 'LogisticRegression'].values[0]
print(best_params_arr)

best_params = eval(best_params_arr[1])

# Inicializa o modelo
model_lr = LogisticRegression(C=best_params["C"],
                              solver=best_params["solver"])

# Treina o modelo
model_lr.fit(text_train, class_train)
# Out:
# ['LogisticRegression' "{'C': 10, 'solver': 'liblinear'}"
#  0.8215384615384617]
# LogisticRegression(C=10, solver='liblinear')

# %% [markdown]
# Support Vector Classification

# %%
from sklearn.svm import SVC

# Recupera o melhor parametro com modelo SVC
best_params_arr = search_results.loc[
                      search_results['Model'] == 'SVC'].values[0]
print(best_params_arr)

best_params = eval(best_params_arr[1])

# Inicializa o modelo
model_svc = SVC(C=best_params["C"],
                kernel=best_params["kernel"])

# Treina o modelo
model_svc.fit(text_train, class_train)
# Out:
# ['SVC' "{'C': 1, 'kernel': 'linear'}" 0.7911538461538461]
# SVC(C=1, kernel='linear')

# %% [markdown]
# # Calcula métricas ⭕

# %%
from sklearn.metrics import accuracy_score, f1_score

# Predições com os modelos treinados
class_pred_nb = model_nb.predict(text_test)
class_pred_lr = model_lr.predict(text_test)
class_pred_svc = model_svc.predict(text_test)

# Calcular as métricas para o Multinomial Naive Bayes
accuracy_nb = accuracy_score(class_test, class_pred_nb)
f1_nb_macro = f1_score(class_test, class_pred_nb, average='macro')
f1_nb_micro = f1_score(class_test, class_pred_nb, average='micro')

# Calcular as métricas para o Logistic Regression
accuracy_lr = accuracy_score(class_test, class_pred_lr)
f1_lr_macro = f1_score(class_test, class_pred_lr, average='macro')
f1_lr_micro = f1_score(class_test, class_pred_lr, average='micro')

# Calcular as métricas para o Support Vector Classification
accuracy_svc = accuracy_score(class_test, class_pred_svc)
f1_svc_macro = f1_score(class_test, class_pred_svc, average='macro')
f1_svc_micro = f1_score(class_test, class_pred_svc, average='micro')

# Exibir os resultados
print(f"Multinomial Naive Bayes:\n Acurácia: {accuracy_nb}"\
      f"\n F1 (Macro): {f1_nb_macro}\n F1 (Micro): {f1_nb_micro}\n")

print(f"Logistic Regression:\n Acurácia: {accuracy_lr}"\
      f"\n F1 (Macro): {f1_lr_macro}\n F1 (Micro): {f1_lr_micro}\n")

print(f"SVC:\n Acurácia: {accuracy_svc}"\
      f"\n F1 (Macro): {f1_svc_macro}\n F1 (Micro): {f1_svc_micro}")
# Out:
# Multinomial Naive Bayes:
#  Acurácia: 0.8269230769230769
#  F1 (Macro): 0.8280531600733372
#  F1 (Micro): 0.8269230769230769
#
# Logistic Regression:
#  Acurácia: 0.8523076923076923
#  F1 (Macro): 0.8524201711609614
#  F1 (Micro): 0.8523076923076923
#
# SVC:
#  Acurácia: 0.81
#  F1 (Macro): 0.8120810054375099
#  F1 (Micro): 0.81

# %% [markdown]
# # Justificativa 🧠

# %% [markdown]
# * **Multinomial Naive Bayes**: O modelo teve um bom desempenho, mas ficou atrás da Logistic Regression em termos de acurácia e F1. O parâmetro alpha foi escolhido como 1.0, o que é o valor padrão para Naive Bayes e geralmente funciona bem em problemas de classificação de texto. O ajuste de suavização impede que o modelo atribua zero de probabilidade a palavras que não aparecem nos dados de treinamento. A escolha de fit_prior=True ajuda o modelo a aprender as distribuições de classes (ao invés de assumir probabilidades iguais), o que é útil se as classes forem desbalanceadas.
#
# * **Logistic Regression**: Foi o modelo que obteve o melhor desempenho entre os três. O valor de C=10 reflete uma escolha para dar mais flexibilidade ao modelo, permitindo uma menor regularização para que o modelo se ajuste melhor aos dados. A escolha do solver 'liblinear' é eficiente e adequada para problemas menores com menos variáveis e um número razoável de amostras.
#
# * **SVC**: O modelo com kernel linear, obteve o pior desempenho dos modelos testados, possivelmente devido à limitação de usar uma separação linear. O valor de C=1 indica uma tentativa de balancear a penalização por erros e a margem do modelo. Usar o kernel linear indica que o modelo foi ajustado para trabalhar com separações lineares, o que pode ser suficiente em problemas de classificação mais simples.
